# %% [markdown]
# # Dashboard for issuing queries to the SparkifyDB
# make sure that you have run `python create_tables.py` and `python etl.py` to populate the database before continuing

# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %%sql
#
# SELECT users.user_id, users.first_name, users.last_name, users.level, Count(*) as num_listens
# FROM songplays
# JOIN users ON songplays.user_id = users.user_id
# GROUP BY users.user_id, users.first_name, users.level
# ORDER BY num_listens DESC
# LIMIT 100
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [(49, 'Chloe', 'Cuevas', 'paid', 689),
#  (80, 'Tegan', 'Levine', 'paid', 665),
#  (97, 'Kate', 'Harrell', 'paid', 557),
#  (15, 'Lily', 'Koch', 'paid', 463),
#  (44, 'Aleena', 'Kirby', 'paid', 397),
#  (29, 'Jacqueline', 'Lynch', 'paid', 346),
#  (24, 'Layla', 'Griffin', 'paid', 321),
#  (73, 'Jacob', 'Klein', 'paid', 289),
#  (88, 'Mohammad', 'Rodriguez', 'paid', 270),
#  (36, 'Matthew', 'Jones', 'paid', 248),
#  (16, 'Rylan', 'George', 'paid', 223),
#  (95, 'Sara', 'Johnson', 'paid', 213),
#  (85, 'Kinsley', 'Young', 'paid', 179),
#  (30, 'Avery', 'Watkins', 'paid', 178),
#  (25, 'Jayden', 'Graves', 'paid', 169),
#  (42, 'Harper', 'Barrett', 'paid', 140),
#  (58, 'Emily', 'Benson', 'paid', 140),
#  (26, 'Ryan', 'Smith', 'free', 114),
#  (82, 'Avery', 'Martinez', 'paid', 87),
#  (72, 'Hayden', 'Brock', 'paid', 72),
#  (32, 'Lily', 'Burns', 'free', 56),
#  (101, 'Jayden', 'Fox', 'free', 55),
# ...
